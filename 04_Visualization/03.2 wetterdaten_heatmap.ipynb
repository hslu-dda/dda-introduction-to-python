# %% [markdown]
# # Heatmap
#
# Quelle: https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/resource/0c200920-8500-4049-8230-cf8b53a61791 <br>
# Metadaten: https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/uzg_ogd_metadaten.json
#
# Was hier passiert
# 1. DF 1992-2026 einlesen
# 2. Eine Heatmap plotten
# 3. Merhere Heatmaps plotten (als einzelne Maps)
# 4. Eine grosse Heatmap aller Jahre (Jahr x Tag)

# %%
import altair as alt
alt.data_transformers.disable_max_rows() # <- Diese Funktion schaltet Altairs Limit für grosse Datensätze aus 
import pandas as pd
from datetime import datetime as dt

# %% [markdown]
# ### DF bereinigen

# %%
df_roh = pd.read_csv('data/weather/zurich_weather_1992-2026_all_values.csv')

# %%
# Datum formatieren


#Einschränken auf Messstation Stampfenbachstrasse 


# abspeichern für Verwendung in anderen Notebooks

# %%
# Einschränken auf Maximaltemperatur, speichern in neuem DF

# %%
df

# %% [markdown]
# ### Eine Heatmap

# %%
# Filtern nach Jahr 2025

# %%
df_25.head(2)

# %%
# unsere erste Heatmap!

# %%
# Wie sieht es 2026 aus?

# Filtern nach Jahr 2025

# %% [markdown]
# ### Mehrere Heatmaps

# %%
# Warum nur ein Heatmap wenn wir alle Jahre haben können =)

# %% [markdown]
# ## Tag-Jahr Heatmap

# %%
# und wir können alle Jahre in einen Plot packen

# %% [markdown]
# Bonus: Was ist mit der Datenlücke 2008?

# %%
# index vor der Datenlücke anzeigen
df[df['Datum'].astype(str)=="2008-08-31 00:00:00+01:00"]

# %%
# 10 Zeilen ab letzem Messwert anzeigen --> Tage sind vorhanden, aber ohne Messwert
df.iloc[6703:6713,:]

# %% [markdown]
# ## Quizz

# %% [markdown]
# 1. nimm den df ```df_roh``` und zeige die ersten 15 Zeilen an.
# 2. Filtere den df nach dem Parameter ```StrGlo```, für die Sonneneinstrahlung  <br>
# (*Die Globalstrahlung ist die gesamte Sonnenstrahlung, die auf den Boden trifft. Sie setzt sich aus direktem Sonnenlicht und gestreuter Himmelsstrahlung zusammen. Einheit: Watt pro Quadratmeter*)
# 3. Speichere den gefilterten DF in einem neuen df ```df_sun```
# 4. Setze einen neuen Index, und lasse den alten weg
# 5. Zeige die ersten 15 Zeilen von ```df_sun``` an

# %%
df_sun.head(15)

# %% [markdown]
# 6. Filtere für das Jahr 2025 und erstelle einen neuen df davon (```df_sun_25```)

# %% [markdown]
# 7. Erstelle ein Heatmap (rainmap :P) für die Sonnenscheindauer im Jahr 2025<br>
# *Tipp: nutze ein anderes Farbschema, zb plasma* <br>*mehr Farbschemas: https://vega.github.io/vega/docs/schemes/*

# %% [markdown]
# 8. Erstelle eine Heatmap für alle Jahre, mit Jahren auf der Y-Achse und den Monats-Tagen auf der X-Achse

# %%
)

# %% [markdown]
# -> Zwischen 2008-2010 gibt es eine Datenlücke. Die anderen Messstationen enthalten jedoch gar keine Sonneneinstrahlung, deshalb leben wir einfach damit.
