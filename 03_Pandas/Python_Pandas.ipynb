# %% [markdown]
# # Pandas in Python Basics

# %% [markdown]
# ## Daten importieren
#
# Falls Pandas noch nicht installiert ist kann dies mit `pip install pandas` nachgeholt werden.

# %%
# Pandas Library importieren
import pandas as pd

# %% [markdown]
# - Pfad zum File definieren
# - CSV importieren mittels Pandas

# %%
file_path = "./data/movies_imdb.csv"
data = pd.read_csv(file_path)

# %% [markdown]
# ## Datenstruktur verstehen
#
# - Pandas Dataframe kennenlernen. Ein pandas DataFrame ist eine tabellenartige Datenstruktur in Python, die Daten in Zeilen und Spalten organisiert und so die Datenanalyse und -bearbeitung erleichtert.
# - Spalten-Namen ausgeben
# - Ersten 5 Einträge ausgeben
# - Einen spezifischen Eintrag an Index-Position `n` ausgeben
# - Eine spezifische Spalte ausgeben

# %%
# What type does "data" have?
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Print the columns of the DataFrame
data.columns
# Out:
# Index(['imdbID', 'title', 'year', 'rating', 'runtime', 'genre', 'released',
#        'director', 'writer', 'cast', 'metacritic', 'imdbRating', 'imdbVotes',
#        'poster', 'plot', 'fullplot', 'language', 'country', 'awards',
#        'lastupdated', 'type'],
#       dtype='object')

# %%
# print the first 5 entries
data.head()
# Out:
#    imdbID                                   title  year     rating runtime  \
# 0       1                              Carmencita  1894  NOT RATED   1 min
# 1       5                        Blacksmith Scene  1893    UNRATED   1 min
# 2       3                          Pauvre Pierrot  1892        NaN   4 min
# 3       8  Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# 4      10   Employees Leaving the Lumi�re Factory  1895        NaN   1 min
#
#                       genre    released              director writer  \
# 0        Documentary, Short         NaN  William K.L. Dickson    NaN
# 1                     Short  1893-05-09  William K.L. Dickson    NaN
# 2  Animation, Comedy, Short  1892-10-28         �mile Reynaud    NaN
# 3        Documentary, Short  1894-01-09  William K.L. Dickson    NaN
# 4        Documentary, Short  1895-03-22         Louis Lumi�re    NaN
#
#                        cast  ...  imdbRating  imdbVotes  \
# 0                Carmencita  ...         5.9     1032.0
# 1  Charles Kayser, John Ott  ...         6.2     1189.0
# 2                       NaN  ...         6.7      566.0
# 3                  Fred Ott  ...         5.9      988.0
# 4                       NaN  ...         6.9     3469.0
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMjAzND...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 plot  \
# 0  Performing on what looks like a small wooden s...
# 1  Three men hammer on an anvil and pass a bottle...
# 2  One night, Arlequin come to see his lover Colo...
# 3  A man (Thomas Edison's assistant) takes a pinc...
# 4  A man opens the big gates to the Lumi�re facto...
#
#                                             fullplot language country  awards  \
# 0  Performing on what looks like a small wooden s...      NaN     USA     NaN
# 1  A stationary camera looks at a large anvil wit...      NaN     USA  1 win.
# 2  One night, Arlequin come to see his lover Colo...      NaN  France     NaN
# 3  A man (Edison's assistant) takes a pinch of sn...      NaN     USA     NaN
# 4  A man opens the big gates to the Lumi�re facto...      NaN  France     NaN
#
#                      lastupdated   type
# 0  2015-08-26 00:03:45.040000000  movie
# 1  2015-08-26 00:03:50.133000000  movie
# 2  2015-08-12 00:06:02.720000000  movie
# 3  2015-08-10 00:21:07.127000000  movie
# 4  2015-08-26 00:03:56.603000000  movie
#
# [5 rows x 21 columns]

# %%
# Print an item on a specific location
data.iloc[10]
# Out:
# imdbID                                                        91
# title                                     The House of the Devil
# year                                                        1896
# rating                                                       NaN
# runtime                                                    3 min
# genre                                              Short, Horror
# released                                                     NaN
# director                                          Georges M�li�s
# writer                                            Georges M�li�s
# cast                               Jeanne d'Alcy, Georges M�li�s
# metacritic                                                   NaN
# imdbRating                                                   6.8
# imdbVotes                                                 1135.0
# poster                                                       NaN
# plot           A bat flies into an ancient castle and transfo...
# fullplot       A bat flies into an ancient castle and transfo...
# language                                                     NaN
# country                                                   France
# awards                                                       NaN
# lastupdated                        2015-08-26 00:06:16.697000000
# type                                                       movie
# Name: 10, dtype: object

# %%
# print a specific column
data["title"]
# Out:
# 0                                    Carmencita
# 1                              Blacksmith Scene
# 2                                Pauvre Pierrot
# 3        Edison Kinetoscopic Record of a Sneeze
# 4         Employees Leaving the Lumi�re Factory
#                           ...
# 46009                         The New Classmate
# 46010        Untitled Christopher Nolan Project
# 46011                    Die Turnschuh-Giganten
# 46012                  The Monster of Mangatiti
# 46013                             The Last Word
# Name: title, Length: 46014, dtype: object

# %% [markdown]
# ## Daten Sortieren
#
# - Daten nach einer Spalte alphabetisch sortieren
# - Daten nach einer Spalte nach Werten sortieren

# %%
sorted_title_az = data.sort_values(by="title", ascending=True)
sorted_title_az.head()
# Out:
#         imdbID                                              title  year  \
# 36921  1699720                              !Women Art Revolution  2010
# 36405  1637976                                #1 Cheerleader Camp  2010
# 43709  3526286                                            #Horror  2015
# 42572  3060338  #chicagoGirl: The Social Network Takes on a Di...  2013
# 8481     68152                                                  $  1971
#
#         rating  runtime                       genre    released  \
# 36921      NaN   83 min                 Documentary  2011-06-01
# 36405  UNRATED   95 min                      Comedy  2010-07-27
# 43709      NaN   90 min      Drama, Horror, Mystery         NaN
# 42572      NaN   74 min  Documentary, Action, Drama  2014-05-18
# 8481         R  121 min        Comedy, Crime, Drama  1971-12-17
#
#                    director                         writer  \
# 36921  Lynn Hershman-Leeson                            NaN
# 36405             Mark Quod  Naomi L. Selfman (screenplay)
# 43709          Tara Subkoff     Tara Subkoff, Tara Subkoff
# 42572        Joe Piscatella                 Joe Piscatella
# 8481         Richard Brooks                 Richard Brooks
#
#                                                     cast  ...  imdbRating  \
# 36921                               Lynn Hershman-Leeson  ...         6.7
# 36405  Charlene Tilton, Seth Cassell, Jay Gillespie, ...  ...         3.8
# 43709  Taryn Manning, Natasha Lyonne, Chlo� Sevigny, ...  ...         NaN
# 42572                                                NaN  ...         7.1
# 8481   Warren Beatty, Goldie Hawn, Gert Fr�be, Robert...  ...         6.5
#
#        imdbVotes                                             poster  \
# 36921      142.0  https://m.media-amazon.com/images/M/MV5BMjE1MD...
# 36405     2421.0  https://m.media-amazon.com/images/M/MV5BMTY3ND...
# 43709        NaN  https://m.media-amazon.com/images/M/MV5BMTU3Mj...
# 42572       77.0  https://m.media-amazon.com/images/M/MV5BMTgwOD...
# 8481      1608.0  https://m.media-amazon.com/images/M/MV5BMzkxMz...
#
#                                                     plot  \
# 36921  Through intimate interviews, provocative art, ...
# 36405  A pair of horny college guys get summer jobs a...
# 43709  Inspired by actual events, a group of 12 year ...
# 42572  From her childhood bedroom in the Chicago subu...
# 8481   A bank security expert plots with a call girl ...
#
#                                                 fullplot         language  \
# 36921  Through intimate interviews, provocative art, ...          English
# 36405  When they're hired to work at a cheerleading c...          English
# 43709  #HORROR is a film about the lives of six young...          English
# 42572  From her childhood bedroom in the Chicago subu...          English
# 8481   Several criminals use safe deposit boxes in a ...  English, German
#
#           country                   awards                    lastupdated  \
# 36921         USA           2 nominations.  2015-04-02 00:54:39.997000000
# 36405         USA                      NaN  2015-09-11 00:12:47.397000000
# 43709         USA                      NaN  2015-08-26 01:08:41.057000000
# 42572  USA, Syria  2 wins & 2 nominations.  2015-09-01 00:08:44.710000000
# 8481          USA            1 nomination.  2015-09-05 00:51:51.667000000
#
#         type
# 36921  movie
# 36405  movie
# 43709  movie
# 42572  movie
# 8481   movie
#
# [5 rows x 21 columns]

# %%
sorted_rating = data.sort_values(by="imdbRating", ascending=False)
sorted_rating.head()
# Out:
#         imdbID                                       title  year rating  \
# 20963   185906                            Band of Brothers  2001  TV-MA
# 29859   795176                                Planet Earth  2006   TV-G
# 12376    87117                   Dances Sacred and Profane  1985      R
# 22854   252487                             The Chaos Class  1975    NaN
# 45443  4487148  The Third Annual 'On Cinema' Oscar Special  2015    NaN
#
#           runtime                   genre    released             director  \
# 20963     705 min  Action, Drama, History  2001-09-09                  NaN
# 29859      60 min             Documentary  2007-03-25                  NaN
# 12376  1 h 30 min             Documentary  1993-03-20  Dan Jury, Mark Jury
# 22854      87 min           Comedy, Drama  1975-04-01        Ertem Egilmez
# 45443     222 min                  Comedy  2015-02-22     Eric Notarnicola
#
#                                                   writer  \
# 20963                                                NaN
# 29859                                                NaN
# 12376                        Mark Jury, Charles Gatewood
# 22854                    Umur Bugay, Rifat Ilgaz (novel)
# 45443  Tim Heidecker, Eric Notarnicola, Andrew Porter...
#
#                                                     cast  ...  imdbRating  \
# 20963  Scott Grimes, Matthew Leitch, Damian Lewis, Ro...  ...         9.6
# 29859               David Attenborough, Sigourney Weaver  ...         9.5
# 12376          Fakir Musafar, Jim Ward, Charles Gatewood  ...         9.5
# 22854  Kemal Sunal, M�nir �zkul, Halit Ak�atepe, Tari...  ...         9.5
# 45443  Kim Delgado, Joe Estevez, Hank Friedmann, Bria...  ...         9.5
#
#        imdbVotes                                             poster  \
# 20963   183802.0  https://m.media-amazon.com/images/M/MV5BMTI3OD...
# 29859    82896.0  https://m.media-amazon.com/images/M/MV5BNzA0NT...
# 12376       19.0                                                NaN
# 22854    22244.0                                                NaN
# 45443       17.0                                                NaN
#
#                                                     plot  \
# 20963  The story of Easy Company of the US Army 101st...
# 29859  Emmy Award winning, 11-episodes, 5-years in th...
# 12376                                                NaN
# 22854  Lazy, uneducated students share a very close b...
# 45443  Tim Heidecker, Gregg Turkington and the rest o...
#
#                                                 fullplot  \
# 20963  This is the story of "E" Easy Company, 506th R...
# 29859  Each 50 minute episode features a global overv...
# 12376                                                NaN
# 22854  Lazy, uneducated students share a very close b...
# 45443  Tim Heidecker, Gregg Turkington and the rest o...
#
#                                          language  country  \
# 20963  English, Dutch, French, German, Lithuanian  UK, USA
# 29859                                     English       UK
# 12376                                         NaN      NaN
# 22854                                     Turkish   Turkey
# 45443                                     English      USA
#
#                                                   awards  \
# 20963  Won 1 Golden Globe. Another 33 wins & 24 nomin...
# 29859  Won 4 Primetime Emmys. Another 10 wins & 14 no...
# 12376                                                NaN
# 22854                                                NaN
# 45443                                                NaN
#
#                          lastupdated    type
# 20963  2015-08-31 00:04:34.187000000  series
# 29859  2015-09-15 05:36:43.637000000  series
# 12376            2012-06-10 00:00:00   movie
# 22854  2015-05-02 02:29:25.447000000   movie
# 45443  2015-07-27 04:34:37.730000000   movie
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Daten Filtern
#
# Um einen Pandas Dataframe zu Filtern wird die Bedingung direkt in die eckigen Klammern geschrieben und das Resultat einer neuen Variable zugewiesen.
#
# ```python
# filtered_data = data[data["year"] == "1989"]
# ```
#
# - Filtere die Daten nach verschiedenen Werten wie dem Jahr oder dem Land.
# - Finde alle Filme mit einem Rating höher als 9
# - Finde alle Filme zwischen 1990 und 1999
# - Finde alle Filme mit dem Genre "Animation"

# %%
movies_1989 = data[data['year'] == "1989"]
movies_1989.head()
# Out:
#        imdbID                               title  year rating  runtime  \
# 7740    64820              The Plot Against Harry  1989    NaN   81 min
# 11098   80755  Things I Like, Things I Don't Like  1989    NaN    8 min
# 11861   84548                       Interrogation  1989    NaN  118 min
# 12968   90334      Wizards of the Lost Kingdom II  1989     PG   80 min
# 13339   92337                       The Decalogue  1989    NaN  572 min
#
#                             genre    released             director  \
# 7740                       Comedy  1990-05-16       Michael Roemer
# 11098               Short, Comedy  1989-01-01   Jean-Pierre Jeunet
# 11861      Crime, Drama, Thriller  1989-12-13     Ryszard Bugajski
# 12968  Action, Fantasy, Adventure  1989-03-01  Charles B. Griffith
# 13339                       Drama  1989-12-10                  NaN
#
#                                     writer  \
# 7740                        Michael Roemer
# 11098  Bruno Delbonnel, Jean-Pierre Jeunet
# 11861       Ryszard Bugajski, Janusz Dymek
# 12968     Charles B. Griffith, Lance Smith
# 13339                                  NaN
#
#                                                     cast  ...  imdbRating  \
# 7740   Martin Priest, Ben Lang, Maxine Woods, Henry Nemo  ...         6.9
# 11098  Dominique Pinon, Chick Ortega, Marie-Laure Dou...  ...         7.8
# 11861  Krystyna Janda, Adam Ferency, Janusz Gajos, Ag...  ...         8.2
# 12968  Mel Welles, Robert Jayne, David Carradine, Sus...  ...         1.8
# 13339  Artur Barcis, Olgierd Lukaszewicz, Olaf Lubasz...  ...         9.2
#
#        imdbVotes                                             poster  \
# 7740       246.0  https://m.media-amazon.com/images/M/MV5BNzg4MT...
# 11098     1556.0                                                NaN
# 11861     1826.0  https://m.media-amazon.com/images/M/MV5BMjAxND...
# 12968      304.0                                                NaN
# 13339    10958.0  https://m.media-amazon.com/images/M/MV5BMTMyMz...
#
#                                                     plot  \
# 7740   A small-time Jewish racketeer, just out of pri...
# 11098  A 9 minute comedy starring Dominique Pinon (De...
# 11861  Tonia goes out drinking. She wakes up in priso...
# 12968  Three kingdoms have been overtaken by three ev...
# 13339  Ten television drama films, each one based on ...
#
#                                                 fullplot language  \
# 7740   A small-time Jewish racketeer, just out of pri...  English
# 11098  A 9 minute comedy starring Dominique Pinon (De...   French
# 11861  Tonia goes out drinking. She wakes up in priso...   Polish
# 12968  Three kingdoms have been overtaken by three ev...  English
# 13339  This is a series of ten shorts created for Pol...   Polish
#
#                     country                   awards  \
# 7740                    USA   1 win & 7 nominations.
# 11098                France                  4 wins.
# 11861                Poland  8 wins & 4 nominations.
# 12968                   USA                      NaN
# 13339  Poland, West Germany                  9 wins.
#
#                          lastupdated    type
# 7740   2015-07-25 00:27:11.930000000   movie
# 11098  2015-09-02 00:31:11.647000000   movie
# 11861  2015-07-30 00:14:47.333000000   movie
# 12968  2015-08-26 00:04:28.447000000   movie
# 13339  2015-08-26 00:25:24.917000000  series
#
# [5 rows x 21 columns]

# %%
movies_japan = data[data["country"] == "Japan"]
len(movies_japan)
# movies_japan.head()
# Out:
# 1468

# %% [markdown]
# Dadurch werden alle Filme gefiltert welche nur in Japan produziert wurden. Filme welche unter anderem in Japan produziert wurden fallen raus da der Wert des Feldes nicht nur das Wort "Japan" enthält sondern bspw. "USA, Japan". Mit `str.contains` wird geschaut ob in einem String (bspw. "USA, Japan") ein Teil "Japan" vorkommt.

# %%
all_movies_japan = data[data["country"].str.contains("Japan", na=False)]
len(all_movies_japan)
#all_movies_japan.head()
# Out:
# 1886

# %%
# All movies with a rating of 9 or higher
best_movies = data[data["imdbRating"] >= 9]
best_sorted = best_movies.sort_values(by="imdbRating", ascending=False)
best_sorted.head()
# Out:
#         imdbID                                       title  year rating  \
# 20963   185906                            Band of Brothers  2001  TV-MA
# 45443  4487148  The Third Annual 'On Cinema' Oscar Special  2015    NaN
# 22854   252487                             The Chaos Class  1975    NaN
# 29859   795176                                Planet Earth  2006   TV-G
# 12376    87117                   Dances Sacred and Profane  1985      R
#
#           runtime                   genre    released             director  \
# 20963     705 min  Action, Drama, History  2001-09-09                  NaN
# 45443     222 min                  Comedy  2015-02-22     Eric Notarnicola
# 22854      87 min           Comedy, Drama  1975-04-01        Ertem Egilmez
# 29859      60 min             Documentary  2007-03-25                  NaN
# 12376  1 h 30 min             Documentary  1993-03-20  Dan Jury, Mark Jury
#
#                                                   writer  \
# 20963                                                NaN
# 45443  Tim Heidecker, Eric Notarnicola, Andrew Porter...
# 22854                    Umur Bugay, Rifat Ilgaz (novel)
# 29859                                                NaN
# 12376                        Mark Jury, Charles Gatewood
#
#                                                     cast  ...  imdbRating  \
# 20963  Scott Grimes, Matthew Leitch, Damian Lewis, Ro...  ...         9.6
# 45443  Kim Delgado, Joe Estevez, Hank Friedmann, Bria...  ...         9.5
# 22854  Kemal Sunal, M�nir �zkul, Halit Ak�atepe, Tari...  ...         9.5
# 29859               David Attenborough, Sigourney Weaver  ...         9.5
# 12376          Fakir Musafar, Jim Ward, Charles Gatewood  ...         9.5
#
#        imdbVotes                                             poster  \
# 20963   183802.0  https://m.media-amazon.com/images/M/MV5BMTI3OD...
# 45443       17.0                                                NaN
# 22854    22244.0                                                NaN
# 29859    82896.0  https://m.media-amazon.com/images/M/MV5BNzA0NT...
# 12376       19.0                                                NaN
#
#                                                     plot  \
# 20963  The story of Easy Company of the US Army 101st...
# 45443  Tim Heidecker, Gregg Turkington and the rest o...
# 22854  Lazy, uneducated students share a very close b...
# 29859  Emmy Award winning, 11-episodes, 5-years in th...
# 12376                                                NaN
#
#                                                 fullplot  \
# 20963  This is the story of "E" Easy Company, 506th R...
# 45443  Tim Heidecker, Gregg Turkington and the rest o...
# 22854  Lazy, uneducated students share a very close b...
# 29859  Each 50 minute episode features a global overv...
# 12376                                                NaN
#
#                                          language  country  \
# 20963  English, Dutch, French, German, Lithuanian  UK, USA
# 45443                                     English      USA
# 22854                                     Turkish   Turkey
# 29859                                     English       UK
# 12376                                         NaN      NaN
#
#                                                   awards  \
# 20963  Won 1 Golden Globe. Another 33 wins & 24 nomin...
# 45443                                                NaN
# 22854                                                NaN
# 29859  Won 4 Primetime Emmys. Another 10 wins & 14 no...
# 12376                                                NaN
#
#                          lastupdated    type
# 20963  2015-08-31 00:04:34.187000000  series
# 45443  2015-07-27 04:34:37.730000000   movie
# 22854  2015-05-02 02:29:25.447000000   movie
# 29859  2015-09-15 05:36:43.637000000  series
# 12376            2012-06-10 00:00:00   movie
#
# [5 rows x 21 columns]

# %% [markdown]
# Um alle Filme zwischen 1990 und 1999 zu finden müssen Zahlen verglichen werden können. Das Problem ist, dass es sich bei den Werten in `data["year"]` um Strings und nicht um Zahlen handelt. Dies lässt sich feststellen in dem der Typ eines Eintrages ausgegeben wird: `print(type(data["year"].iloc[10]))`.
#
# Um das Problem zu umgehen müssen die Strings in Zahlen konvertiert werden. Dazu kann dem Dataframe eine neue Spalte hinzugefügt werden mit `data['year_numeric']`. In diese Spalte werden die konvertierten Werte gespeichert. Dadurch bleiben die uhrsprünglichen Werte in der Spalte "Year" vorhanden. Um die Werte umzurechnen kann auf eine Pandas Funktion zurückgegriffen werden: `pd.to_numeric(data['year'], errors='coerce')`

# %%
# Print the type of a year entry
print(type(data["year"].iloc[10]))

# Convert the 'year' column to numeric, coercing errors (e.g., invalid strings will become NaN)
data['year_numeric'] = pd.to_numeric(data['year'], errors='coerce')

# apply the filtering
movies_90s = data[(data['year_numeric'] >= 1990) & (data['year_numeric'] <= 1999)]
movies_90s.head()
# Out:
# <class 'str'>
#        imdbID                            title  year   rating  runtime  \
# 7777    64994                Larks on a String  1990      NaN   94 min
# 11177   81145                   Me and the Kid  1993       PG   94 min
# 13014   90665  Halfaouine: Boy of the Terraces  1990  UNRATED   98 min
# 13757   94333       The Witching of Ben Wagner  1990        G   96 min
# 13840   94841              The House of Smiles  1991      NaN  110 min
#
#                         genre    released         director  \
# 7777   Comedy, Drama, Romance  1990-02-01      Jir� Menzel
# 11177    Comedy, Crime, Drama  1993-10-22       Dan Curtis
# 13014           Drama, Comedy         NaN  F�rid Boughedir
# 13757                     NaN         NaN      Paul Annett
# 13840          Drama, Romance  1991-03-01    Marco Ferreri
#
#                                                   writer  \
# 7777                 Bohumil Hrabal (novel), Jir� Menzel
# 11177  Stanley Cohen (novel), Richard Tannenbaum (scr...
# 13014  F�rid Boughedir, Nouri Bouzid, Taoufik Jebali ...
# 13757        Mary Jane Auch (novel), Malcolm Marmorstein
# 13840      Liliane Betti, Marco Ferreri, Antonino Marino
#
#                                                     cast  ...  imdbVotes  \
# 7777   Rudolf Hrus�nsk�, Vlastimil Brodsk�, V�clav Ne...  ...     1081.0
# 11177  Danny Aiello, Alex Zuckerman, Joe Pantoliano, ...  ...      189.0
# 13014  Selim Boughedir, Mustapha Adouani, Rabia Ben A...  ...      826.0
# 13757  Sam Bottoms, Harriet Hall, Bettina Rae, Justin...  ...      134.0
# 13840  Ingrid Thulin, Dado Ruspoli, Enzo Cannavale, N...  ...      133.0
#
#                                                   poster  \
# 7777   https://m.media-amazon.com/images/M/MV5BMTE5OT...
# 11177  https://m.media-amazon.com/images/M/MV5BMTIwMT...
# 13014  https://m.media-amazon.com/images/M/MV5BNzk3Nj...
# 13757                                                NaN
# 13840                                                NaN
#
#                                                     plot  \
# 7777   Set in the late 1940s, the film concerns the t...
# 11177  A lonely and emotionally neglected rich kid fo...
# 13014  A coming-of-age comedy/drama set in Tunisia. T...
# 13757  Ben Wagner and his family are moving to a new ...
# 13840  A septuagenarian couple are attracted to each ...
#
#                                                 fullplot         language  \
# 7777   Prague in the early 1950's. Bourgeois elements...            Czech
# 11177  Two ex-cons, Harry (Aiello) and Roy (Pantolian...          English
# 13014  A coming-of-age comedy/drama set in Tunisia. T...           Arabic
# 13757  [Contains spoilers] "George Wagner (Sam Bottom...          English
# 13840  Adelina, a former "Miss Smiles" beauty queen, ...  Italian, French
#
#                       country                  awards  \
# 7777           Czechoslovakia                 3 wins.
# 11177                     USA                     NaN
# 13014  Tunisia, France, Italy  4 wins & 1 nomination.
# 13757                     USA          2 nominations.
# 13840                   Italy  1 win & 7 nominations.
#
#                          lastupdated   type year_numeric
# 7777   2015-09-02 00:42:33.240000000  movie       1990.0
# 11177  2015-08-25 00:20:34.790000000  movie       1993.0
# 13014  2015-09-02 00:26:48.883000000  movie       1990.0
# 13757  2015-08-09 00:51:36.943000000  movie       1990.0
# 13840  2015-08-13 00:06:59.537000000  movie       1991.0
#
# [5 rows x 22 columns]

# %%
# Filter movies of a certain genre
all_animation = data[data["genre"].str.contains("Animation", na=False)]
all_animation.head()
# Out:
#     imdbID                                     title  year rating runtime  \
# 2        3                            Pauvre Pierrot  1892    NaN   4 min
# 36     516                        The Electric Hotel  1908    NaN   8 min
# 41     554            Humorous Phases of Funny Faces  1906    NaN   3 min
# 44     682                                 A Fantasy  1908    NaN   2 min
# 55    1527  The Revenge of a Kinematograph Cameraman  1912    NaN  12 min
#
#                         genre    released             director  \
# 2    Animation, Comedy, Short  1892-10-28        �mile Reynaud
# 36           Animation, Short  1908-12-19    Segundo de Chom�n
# 41   Animation, Short, Comedy  1906-04-06   J. Stuart Blackton
# 44  Animation, Short, Fantasy  1908-08-17           �mile Cohl
# 55   Animation, Short, Comedy  1912-10-27  Wladyslaw Starewicz
#
#                  writer                                 cast  ...  imdbVotes  \
# 2                   NaN                                  NaN  ...      566.0
# 36                  NaN  Segundo de Chom�n, Julienne Mathieu  ...      481.0
# 41                  NaN                   J. Stuart Blackton  ...      625.0
# 44                  NaN                                  NaN  ...     1245.0
# 55  Wladyslaw Starewicz                                  NaN  ...     1593.0
#
#                                                poster  \
# 2                                                 NaN
# 36                                                NaN
# 41                                                NaN
# 44                                                NaN
# 55  https://m.media-amazon.com/images/M/MV5BMTczOD...
#
#                                                  plot  \
# 2   One night, Arlequin come to see his lover Colo...
# 36  According to the rapid strides that electricit...
# 41  A cartoonist draws faces and figures on a blac...
# 44  The first all-animated film in history, a seri...
# 55  A jilted husband takes his revenge by filming ...
#
#                                              fullplot language        country  \
# 2   One night, Arlequin come to see his lover Colo...      NaN         France
# 36  According to the rapid strides that electricit...      NaN  Spain, France
# 41  Considered the first truly animated movie (or ...      NaN            USA
# 44  The first all-animated film in history, a seri...      NaN         France
# 55  A jilted husband takes his revenge by filming ...      NaN         Russia
#
#    awards                    lastupdated   type year_numeric
# 2     NaN  2015-08-12 00:06:02.720000000  movie       1892.0
# 36    NaN  2015-08-29 00:28:28.703000000  movie       1908.0
# 41    NaN  2015-08-29 00:29:22.593000000  movie       1906.0
# 44    NaN  2015-08-29 00:33:10.437000000  movie       1908.0
# 55    NaN  2015-08-25 00:00:33.727000000  movie       1912.0
#
# [5 rows x 22 columns]

# %%
all_90s_action = movies_90s[(movies_90s["genre"].str.contains("Action", na=False))]
all_90s_action.head()
# Out:
#        imdbID                                  title  year rating  runtime  \
# 14201   96875                              Catchfire  1990      R  116 min
# 14402   97910                                Moon 44  1990      R   98 min
# 14536   98467              They Call Me Macho Woman!  1991    NaN   81 min
# 14590   98965  3 Little Ninjas and the Lost Treasure  1990    NaN  100 min
# 14591   98967                          Boiling Point  1990    NaN   96 min
#
#                           genre    released            director  \
# 14201     Action, Comedy, Crime  1990-04-03       Dennis Hopper
# 14402  Action, Sci-Fi, Thriller  1990-02-15     Roland Emmerich
# 14536            Action, Comedy  1991-02-01  Patrick G. Donahue
# 14590                    Action         NaN       Emmett Alston
# 14591     Action, Comedy, Crime  1990-09-15      Takeshi Kitano
#
#                                                   writer  \
# 14201  Rachel Kronstadt Mann (story), Rachel Kronstad...
# 14402  Dean Heyde (screenplay), Oliver Eberle (screen...
# 14536                                 Patrick G. Donahue
# 14590                               Douglas Ivan (story)
# 14591                        Takeshi Kitano (screenplay)
#
#                                                     cast  ...  imdbVotes  \
# 14201  Dennis Hopper, Jodie Foster, Dean Stockwell, V...  ...    2441.00
# 14402  Michael Par�, Lisa Eichhorn, Dean Devlin, Bria...  ...    3377.00
# 14536  Debra Sweaney, Brian Oldfield, Sean P. Donahue...  ...     100.00
# 14590  Douglas Ivan, Steven Nelson, Jonathan Anzaldo,...  ...     681.00
# 14591  Takeshi Kitano, Y�rei Yanagi, Yuriko Ishida, G...  ...    4247.00
#
#                                                   poster  \
# 14201  https://m.media-amazon.com/images/M/MV5BMTI5ND...
# 14402  https://m.media-amazon.com/images/M/MV5BMTYxND...
# 14536                                                NaN
# 14590  https://m.media-amazon.com/images/M/MV5BMTk3OT...
# 14591  https://m.media-amazon.com/images/M/MV5BMjEwMj...
#
#                                                     plot  \
# 14201  A witness to a mob assassination flees for her...
# 14402  Year 2038: The mineral resources of the earth ...
# 14536  Tromatic Super Heroine Susan Morris has to lea...
# 14590  A treasure map found by three young boys allow...
# 14591  Two disquieted junior baseball players seek re...
#
#                                                 fullplot  language  \
# 14201  An artist (Foster) witnesses a Mafia hit and c...   English
# 14402  Year 2038: The mineral resources of the earth ...   English
# 14536  Tromatic Super Heroine Susan Morris has to lea...   English
# 14590  A treasure map found by three young boys allow...   English
# 14591  Two members of a Japanese junior baseball team...  Japanese
#
#             country                 awards                    lastupdated  \
# 14201           USA                    NaN  2015-08-17 00:56:01.687000000
# 14402  West Germany                2 wins.  2015-09-14 07:21:20.667000000
# 14536           USA          1 nomination.  2015-05-22 10:56:01.243000000
# 14590           USA                    NaN  2015-08-23 00:54:50.373000000
# 14591         Japan  1 win & 1 nomination.  2015-09-02 00:23:09.287000000
#
#         type year_numeric
# 14201  movie      1990.00
# 14402  movie      1990.00
# 14536  movie      1991.00
# 14590  movie      1990.00
# 14591  movie      1990.00
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Basic Statistics
#
# - Berechne den Mean und Median der Ratings. Der Mittelwert (Mean) ist der Durchschnitt, der berechnet wird, indem alle Werte addiert und durch die Anzahl der Werte geteilt werden. Der Median hingegen ist der mittlere Wert in einer sortierten Datenreihe, der die Daten in zwei Hälften teilt – unabhängig von extremen Ausreißern.
# - Berechne den häufigsten Wert (Mode)
# - Finde den niedrigsten und höchsten Wert.

# %% [markdown]
# When using `.describe()` some numbers are given in scientific notation (also called exponential notation).
#
# 4.934499e+04 means: 4.934499 x 10^4
# Which equals: 49344.99

# %%
# .describe() outputs all popular statistics of a data set.
# Disable scientific notation for floats
pd.set_option('display.float_format', '{:.2f}'.format)
data.describe()
# Out:
#           imdbID  metacritic  imdbRating  imdbVotes  year_numeric
# count   46014.00     9401.00    44300.00   44299.00      45938.00
# mean   855206.22       56.90        6.38   11800.55       1991.13
# std   1141978.79       17.72        1.18   49344.99         23.91
# min         1.00        1.00        1.10       5.00       1874.00
# 25%     81657.50       45.00        5.80     326.00       1977.00
# 50%    252487.50       58.00        6.60     999.00       2000.00
# 75%   1370867.50       70.00        7.20    3829.00       2010.00
# max   5023260.00      100.00        9.60 1521105.00       2019.00

# %%
# Calculate the mean
mean_rating = data['imdbRating'].mean()

# Calculate the median
median_rating = data['imdbRating'].median()

# Print the results
print(f"Mean IMDb Rating: {mean_rating}")
print(f"Median IMDb Rating: {median_rating}")
# Out:
# Mean IMDb Rating: 6.381453724604965
# Median IMDb Rating: 6.6

# %%
# der häufigste wert
data['imdbRating'].mode()
# Out:
# 0   7.20
# Name: imdbRating, dtype: float64

# %%
# Min & Max
print(f"Lowest Rating:: {data['imdbRating'].min()}")
print(f"Highest Rating: {data['imdbRating'].max()}")
# Out:
# Lowest Rating:: 1.1
# Highest Rating: 9.6

# %% [markdown]
# ## Export
#
# - Exportiere einer der gefilterten Datensätze als neues CSV.
# - Exportiere den selben Datensatz auch als JSON und Excel File

# %%
export_path = './export/movies_90s_action.csv'
all_90s_action.to_csv(export_path, index=False)

# %%
all_90s_action.to_json('./export/movies_90s_action.json', orient='records')

# %%
all_90s_action.to_excel('./export/movies_90s_action.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 all_90s_action.to_excel('./export/movies_90s_action.xlsx', index=False)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/io/formats/excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)
#      66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'
