# %% [markdown]
# # Introduction to Data Analysis with Pandas
#
# [Pandas](https://pandas.pydata.org/) ist eine Library und der de-facto Industry Standart für die Datenanalyse in Python. Installiere Pandas in deinem Environment mit `pip install pandas`.

# %% [markdown]
# ## Daten importieren
#
# Pandas kann eine vielzahl von Files öffnen, darunter `.csv`, `.excel` oder `.txt`.

# %%
# Pandas Library importieren
import pandas as pd
data = pd.read_excel("./data/african_countries_dataset.xlsx", sheet_name="Data")

# %%
# Verifiziere das der Import funktioniert hat
data.head()
# Out:
#            Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 0       Algeria           ag         2381740.0        2381740.0
# 1        Angola           ao         1246700.0        1246700.0
# 2         Benin           bn          112622.0         110622.0
# 3      Botswana           bc          581730.0         566730.0
# 4  Burkina Faso           uv          274200.0         273800.0
#
#    Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 0                0.0             998                          17.3
# 1                0.0            1600                          36.8
# 2             2000.0             121                          43.1
# 3            15000.0               0                          45.6
# 4              400.0               0                          53.2
#
#    Landnutzung_Wald_%  Landnutzung_Other_%  Bevölkerung  Medianalter  \
# 0                 0.8                 81.8   47022473.0         29.1
# ...

# %% [markdown]
# ## Datenstruktur verstehen
#
# - Ein pandas DataFrame ist eine tabellenartige Datenstruktur in Python, die Daten in Zeilen und Spalten organisiert.
# - Spalten-Namen ausgeben
# - Ersten 5 Einträge ausgeben
# - Einen spezifischen Eintrag an Index-Position `n` ausgeben
# - Eine spezifische Spalte ausgeben

# %%
# What type does "data" have?
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Print the columns of the DataFrame
data.columns
# Out:
# Index(['Land', 'Country_Code', 'Fläche_Total_km2', 'Fläche_Land_km2',
#        'Fläche_Wasser_km2', 'Küstenlänge_km', 'Landnutzung_Landwirtschaft_%',
#        'Landnutzung_Wald_%', 'Landnutzung_Other_%', 'Bevölkerung',
#        'Medianalter', 'Lebenserwartung', 'Urbanisierung_%',
#        'Bevölkerungswachstum_%', 'BIP_pro_Kopf_USD', 'Arbeitslosigkeit_%',
#        'Jugendarbeitslosigkeit_%', 'Alphabetisierung_M_%',
#        'Alphabetisierung_F_%', 'Internetnutzer_%'],
#       dtype='object')

# %%
# print the first 5 entries
data.head()
# Out:
#            Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 0       Algeria           ag         2381740.0        2381740.0
# 1        Angola           ao         1246700.0        1246700.0
# 2         Benin           bn          112622.0         110622.0
# 3      Botswana           bc          581730.0         566730.0
# 4  Burkina Faso           uv          274200.0         273800.0
#
#    Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 0                0.0             998                          17.3
# 1                0.0            1600                          36.8
# 2             2000.0             121                          43.1
# 3            15000.0               0                          45.6
# 4              400.0               0                          53.2
#
#    Landnutzung_Wald_%  Landnutzung_Other_%  Bevölkerung  Medianalter  \
# 0                 0.8                 81.8   47022473.0         29.1
# ...

# %%
# print the first n entries
data.head(10)
# Out:
#                   Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 0              Algeria           ag       2381740.000        2381740.0
# 1               Angola           ao       1246700.000        1246700.0
# 2                Benin           bn        112622.000         110622.0
# 3             Botswana           bc        581730.000         566730.0
# 4         Burkina Faso           uv        274200.000         273800.0
# 5              Burundi           by         27830.000          25680.0
# 6  C&ocirc;te d'Ivoire           iv        322463.000         318003.0
# 7           Cabo Verde           cv          4033.000           4033.0
# 8             Cameroon           cm        475440.000         472710.0
# 9                 Chad           cd             1.284        1259200.0
#
#    Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 0                0.0             998                          17.3
# ...

# %%
# print the last 5 entries
data.tail()
# Out:
#                         Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 51                    Uganda           ug          241038.0         197100.0
# 52            Western Sahara           wi               NaN         266000.0
# 53                    Zambia           za          752618.0         743398.0
# 54                  Zimbabwe           zi          390757.0         386847.0
# 55  Central African Republic           ct          622984.0         622984.0
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 51            43938.0               0                          71.9
# 52                0.0            1110                          18.8
# 53             9220.0               0                          32.1
# 54             3910.0               0                          39.5
# 55                0.0               0                           9.0
#
#     Landnutzung_Wald_%  Landnutzung_Other_%  Bevölkerung  Medianalter  \
# ...

# %%
# print/access an item on a specific location, index starts at 0!
data.iloc[2]
# Out:
# Land                                 Benin
# Country_Code                            bn
# Fläche_Total_km2                  112622.0
# Fläche_Land_km2                   110622.0
# Fläche_Wasser_km2                   2000.0
# Küstenlänge_km                         121
# Landnutzung_Landwirtschaft_%          43.1
# Landnutzung_Wald_%                    26.9
# Landnutzung_Other_%                   30.0
# Bevölkerung                     14697052.0
# Medianalter                           17.2
# Lebenserwartung                       63.0
# Urbanisierung_%                       50.1
# Bevölkerungswachstum_%                3.29
# BIP_pro_Kopf_USD                    3700.0
# Arbeitslosigkeit_%                    1.45
# Jugendarbeitslosigkeit_%               3.9
# Alphabetisierung_M_%                  56.9
# Alphabetisierung_F_%                  35.0
# Internetnutzer_%                      34.0
# Name: 2, dtype: object

# %%
# print/access a specific column, also helpful to get index numbers
data["Land"]
# Out:
# 0                      Algeria
# 1                       Angola
# 2                        Benin
# 3                     Botswana
# 4                 Burkina Faso
# 5                      Burundi
# 6          C&ocirc;te d'Ivoire
# 7                   Cabo Verde
# 8                     Cameroon
# 9                         Chad
# 10                     Comoros
# 11         Congo (Brazzaville)
# 12                         DRC
# 13                    Djibouti
# 14                       Egypt
# 15           Equatorial Guinea
# 16                     Eritrea
# 17                    Eswatini
# 18                    Ethiopia
# 19                       Gabon
# 20                       Ghana
# 21                      Guinea
# 22               Guinea-Bissau
# 23                       Kenya
# 24                     Lesotho
# 25                     Liberia
# 26                       Libya
# 27                  Madagascar
# 28                      Malawi
# 29                        Mali
# ...

# %%
# generate a subset based on the index number, e.g. all countries with letter C
# Python slices are start inclusive, end exclusive, so 6:12 gives you rows 6 through 11.
subset = data.iloc[6:12]
subset
# Out:
#                    Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 6   C&ocirc;te d'Ivoire           iv        322463.000         318003.0
# 7            Cabo Verde           cv          4033.000           4033.0
# 8              Cameroon           cm        475440.000         472710.0
# 9                  Chad           cd             1.284        1259200.0
# 10              Comoros           cn          2235.000           2235.0
# 11  Congo (Brazzaville)           cf        342000.000         341500.0
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 6              4460.0             515                          84.2
# 7                 0.0             965                          19.6
# 8              2730.0             402                          20.6
# 9             24800.0               0                          40.0
# 10                0.0             340                          71.5
# ...

# %% [markdown]
# ## Über Datenframe Iterieren

# %%
# Über Columns iterieren
for col in data.columns:
    print(col)
# Out:
# Land
# Country_Code
# Fläche_Total_km2
# Fläche_Land_km2
# Fläche_Wasser_km2
# Küstenlänge_km
# Landnutzung_Landwirtschaft_%
# Landnutzung_Wald_%
# Landnutzung_Other_%
# Bevölkerung
# Medianalter
# Lebenserwartung
# Urbanisierung_%
# Bevölkerungswachstum_%
# BIP_pro_Kopf_USD
# Arbeitslosigkeit_%
# Jugendarbeitslosigkeit_%
# Alphabetisierung_M_%
# Alphabetisierung_F_%
# Internetnutzer_%

# %%
# Über items iterieren
for idx, row in data.iterrows():
    print(idx, row)
# Out:
# 0 Land                                Algeria
# Country_Code                             ag
# Fläche_Total_km2                2381740.000
# Fläche_Land_km2                 2381740.000
# Fläche_Wasser_km2                     0.000
# Küstenlänge_km                          998
# Landnutzung_Landwirtschaft_%         17.300
# Landnutzung_Wald_%                    0.800
# Landnutzung_Other_%                  81.800
# Bevölkerung                    47022473.000
# Medianalter                          29.100
# Lebenserwartung                      77.900
# Urbanisierung_%                      75.300
# Bevölkerungswachstum_%                1.540
# BIP_pro_Kopf_USD                  15200.000
# Arbeitslosigkeit_%                   11.810
# Jugendarbeitslosigkeit_%             30.800
# Alphabetisierung_M_%                 87.400
# Alphabetisierung_F_%                 75.300
# Internetnutzer_%                     71.000
# Name: 0, dtype: object
# 1 Land                                 Angola
# ...

# %% [markdown]
# ## Basic Statistics
#
# Pandas bietet eine ganze Reihe von eingebauten Funktionen um einfache und komplexe Statistiken zu einem Datensatz auszugeben, darunter `.mean()`, `.median()`, `,mode()`, `.min()` und `.max()`.
#
# - Der Mittelwert (Mean) ist der Durchschnitt, der berechnet wird, indem alle Werte addiert und durch die Anzahl der Werte geteilt werden.
# - Der Median hingegen ist der mittlere Wert in einer sortierten Datenreihe, der die Daten in zwei Hälften teilt – unabhängig von extremen Ausreißern. Sollte es sich um eine gerade Anzahl von Werten handeln so ist der Median das Mittel der beiden mittleren Werte.
# - Mode bezeichnet den häufigsten Wert in einer Zahlenreihe. Es kann auch mehrere Modalwerte geben wenn mehrere Zahlen gleich häufig vorkommen.
# - Min. und Max. bezeichnen den niedrigsten, bzw. höchsten Wert in einer sortierten oder unsortierten Zahlenreihe.

# %% [markdown]
# ### Describe
#
# Standardmäßig zeigt Pandas bei DataFrame.describe() sehr viele Nachkommastellen oder wissenschaftliche Notation (1.234567e+06) an. Das kann unübersichtlich wirken – besonders, wenn man die Zahlen nur überblicken und nicht hochpräzise weiterverarbeiten möchte. Über folgenden command kannst du alle Fließkommazahlen mit genau zwei Nachkommastellen anzeigen. Dadurch wird der Vergleich zwischen Spalten einfacher.

# %%
# .describe() outputs all popular statistics of a data set.
# Disable scientific notation for floats
pd.set_option('display.float_format', '{:.3f}'.format)
summary = data.describe()

summary
# Out:
#        Fläche_Total_km2  Fläche_Land_km2  Fläche_Wasser_km2  Küstenlänge_km  \
# count            55.000           55.000             55.000          56.000
# mean         505573.210       534609.673          10466.600         734.750
# std          592731.876       592585.679          22013.958        1008.875
# min               1.267          455.000              0.000           0.000
# 25%           33240.000        47191.000             70.000           0.000
# 50%          267667.000       273800.000           2400.000         345.000
# 75%          775999.000       854545.000          10660.000         973.250
# max         2381740.000      2381740.000         129813.000        4828.000
#
#        Landnutzung_Landwirtschaft_%  Landnutzung_Wald_%  Landnutzung_Other_%  \
# count                        56.000              56.000               56.000
# mean                         46.345              26.762               26.893
# ...

# %% [markdown]
# ### Mean, Median, Min. und Max.

# %%
# Calculate the mean
mean_arbeitslosigkeit = data['Arbeitslosigkeit_%'].mean()

# Calculate the median
median_arbeitslosigkeit = data['Arbeitslosigkeit_%'].median()

# Get the min
min_arbeitslosigkeit = data['Arbeitslosigkeit_%'].min()

# Get the max
max_arbeitslosigkeit = data['Arbeitslosigkeit_%'].max()

# Print the results
print(f"Mean Arbeitslosigkeit(%): {mean_arbeitslosigkeit}")
print(f"Median Arbeitslosigkeit(%): {median_arbeitslosigkeit}")
print(f"Min. Arbeitslosigkeit(%): {min_arbeitslosigkeit}")
print(f"Max. Arbeitslosigkeit(%): {max_arbeitslosigkeit}")
# Out:
# Mean Arbeitslosigkeit(%): 9.174444444444443
# Median Arbeitslosigkeit(%): 5.890000000000001
# Min. Arbeitslosigkeit(%): 0.55
# Max. Arbeitslosigkeit(%): 37.64

# %%
# Get index of min and max
idx_min = data['Arbeitslosigkeit_%'].idxmin()
idx_max = data['Arbeitslosigkeit_%'].idxmax()

# Get full rows
row_min = data.loc[idx_min]
row_max = data.loc[idx_max]

# Do something with it
print("Row with min:", row_min["Land"])
print("Row with max:", row_max["Land"])
# Out:
# Row with min: Niger
# Row with max: Eswatini

# %% [markdown]
# ## Daten Sortieren

# %%
sorted_by_size = data.sort_values(by="Fläche_Total_km2", ascending=False)
sorted_by_size.head()
# Out:
#        Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 0   Algeria           ag       2381740.000      2381740.000
# 12      DRC           cg       2344858.000      2267048.000
# 45    Sudan           su       1861484.000      1731671.000
# 26    Libya           ly       1759540.000      1759540.000
# 1    Angola           ao       1246700.000      1246700.000
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 0               0.000             998                        17.300
# 12          77810.000              37                        15.500
# 45         129813.000             853                        60.300
# 26              0.000            1770                         8.700
# 1               0.000            1600                        36.800
#
#     Landnutzung_Wald_%  Landnutzung_Other_%   Bevölkerung  Medianalter  \
# 0                0.800               81.800  47022473.000       29.100
# ...

# %% [markdown]
# ## Daten Filtern & Subsets erstellen

# %% [markdown]
# ### Random Sample

# %%
# generate a random sample of countries
random_subset = data.sample(n=5, random_state=42)
random_subset
# Out:
#           Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 0      Algeria           ag       2381740.000      2381740.000
# 5      Burundi           by         27830.000        25680.000
# 33  Mozambique           mz        799380.000       786380.000
# 13    Djibouti           dj         23200.000        23180.000
# 19       Gabon           gb        267667.000       257667.000
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 0               0.000             998                        17.300
# 5            2150.000               0                        82.800
# 33          13000.000            2470                        52.700
# 13             20.000             314                        73.500
# 19          10000.000             885                         8.400
#
#     Landnutzung_Wald_%  Landnutzung_Other_%  Bevölkerung  Medianalter  \
# 0                0.800               81.800 47022473.000       29.100
# ...

# %% [markdown]
# ### Filtern nach Werten
#
# Um einen Pandas Dataframe zu Filtern wird die Bedingung direkt in die eckigen Klammern geschrieben und das Resultat einer neuen Variable zugewiesen.

# %%
# filtering for an absolute value
landlocked_countries = data[data["Küstenlänge_km"] == 0]
landlocked_countries.head()
# Out:
#             Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 3       Botswana           bc        581730.000       566730.000
# 4   Burkina Faso           uv        274200.000       273800.000
# 5        Burundi           by         27830.000        25680.000
# 9           Chad           cd             1.284      1259200.000
# 17      Eswatini           wz         17364.000        17204.000
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 3           15000.000               0                        45.600
# 4             400.000               0                        53.200
# 5            2150.000               0                        82.800
# 9           24800.000               0                        40.000
# 17            160.000               0                        69.500
#
#     Landnutzung_Wald_%  Landnutzung_Other_%  Bevölkerung  Medianalter  \
# 3               26.500               27.900  2450668.000       27.100
# ...

# %%
# filtering above or below a certain value
live_expectency_mean = data["Lebenserwartung"].mean()
print("Durschnittliche Lebenserwartung: ", live_expectency_mean)

live_expectency_above_avg = data[data["Lebenserwartung"] > live_expectency_mean]
live_expectency_above_avg.head()
# Out:
# Durschnittliche Lebenserwartung:  67.32321428571429
#                    Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 0               Algeria           ag       2381740.000      2381740.000
# 5               Burundi           by         27830.000        25680.000
# 7            Cabo Verde           cv          4033.000         4033.000
# 10              Comoros           cn          2235.000         2235.000
# 11  Congo (Brazzaville)           cf        342000.000       341500.000
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 0               0.000             998                        17.300
# 5            2150.000               0                        82.800
# 7               0.000             965                        19.600
# 10              0.000             340                        71.500
# 11            500.000             169                        31.300
#
# ...

# %%
# filtering within a range, e.g. based on quantiles
q1 = data['Lebenserwartung'].quantile(0.25)
q3 = data['Lebenserwartung'].quantile(0.75)

central_half = data[(data["Lebenserwartung"] > q1) & (data["Lebenserwartung"] < q3)]
central_half.head()
# Out:
#                   Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 3             Botswana           bc        581730.000       566730.000
# 4         Burkina Faso           uv        274200.000       273800.000
# 5              Burundi           by         27830.000        25680.000
# 6  C&ocirc;te d'Ivoire           iv        322463.000       318003.000
# 8             Cameroon           cm        475440.000       472710.000
#
#    Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 3          15000.000               0                        45.600
# 4            400.000               0                        53.200
# 5           2150.000               0                        82.800
# 6           4460.000             515                        84.200
# 8           2730.000             402                        20.600
#
#    Landnutzung_Wald_%  Landnutzung_Other_%  Bevölkerung  Medianalter  \
# ...

# %% [markdown]
# ### Zwischenaufgabe
#
# Schau dir alle Länder in der Excel Liste an: Ein Land wird dir auffallen da es nicht zu Afrika gehört. Füge in der unteren Zelle Code hinzu welcher dieses Land aus dem Datensatz herausfiltert so das du nachher einen Datensatz mit ausschliesslich afrikanischen Ländern hast.

# %%
# deine Lösung:

# %% [markdown]
# ### Filtern von Zeilen mit Fehlenden Daten

# %%
# to drop all rows were some data is missing
print("Original length: ", len(data))

complete_set = data.dropna()
print("Complete Rows: ", len(complete_set))
# Out:
# Original length:  56
# Complete Rows:  49

# %%
# it is also possible to get all rows with missing values
# isna() → True/False for each cell
# .any(axis=1) → True if any column in that row is missing
incomplete_set = data[data.isna().any(axis=1)]
incomplete_set
# Out:
#               Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 13        Djibouti           dj         23200.000        23180.000
# 16         Eritrea           er        117600.000       101000.000
# 40      Seychelles           se           455.000          455.000
# 42         Somalia           so        637657.000       627337.000
# 44     South Sudan           od        644329.000              NaN
# 46     Switzerland           sz         41277.000        39997.000
# 52  Western Sahara           wi               NaN       266000.000
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 13             20.000             314                        73.500
# 16          16600.000            2234                        62.700
# 40              0.000             491                         3.400
# 42          10320.000            3025                        70.300
# 44                NaN               0                        44.700
# ...

# %% [markdown]
# ### Filtern nach Liste

# %%
# select a subset of countries based on their names
north_africa = [
    "Algeria",
    "Egypt",
    "Libya",
    "Mauritania",
    "Morocco",
    "Sudan",
    "Tunisia",
    "Western Sahara"
]

na_subset = data[data["Land"].isin(north_africa)]
na_subset
# Out:
#               Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 0          Algeria           ag       2381740.000      2381740.000
# 14           Egypt           eg       1001450.000       995450.000
# 26           Libya           ly       1759540.000      1759540.000
# 30      Mauritania           mr       1030700.000      1030700.000
# 32         Morocco           mo        716550.000       716300.000
# 45           Sudan           su       1861484.000      1731671.000
# 50         Tunisia           ts        163610.000       155360.000
# 52  Western Sahara           wi               NaN       266000.000
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 0               0.000             998                        17.300
# 14           6000.000            2450                         4.100
# 26              0.000            1770                         8.700
# 30              0.000             754                        38.500
# ...

# %% [markdown]
# ### Filtern von Spalten

# %%
# select only certain columns
col_selection = ["Land", "Fläche_Total_km2", "Landnutzung_Landwirtschaft_%", "Landnutzung_Wald_%"]
col_subset = data[col_selection]

col_subset.head()
# Out:
#            Land  Fläche_Total_km2  Landnutzung_Landwirtschaft_%  \
# 0       Algeria       2381740.000                        17.300
# 1        Angola       1246700.000                        36.800
# 2         Benin        112622.000                        43.100
# 3      Botswana        581730.000                        45.600
# 4  Burkina Faso        274200.000                        53.200
#
#    Landnutzung_Wald_%
# 0               0.800
# 1              52.500
# 2              26.900
# 3              26.500
# 4              22.400

# %% [markdown]
# ## Data Views vs. Copies 🔮
#
# In Pandas passiert oft etwas Unerwartetes: Wenn du bspw. schreibst `na_subset = data[data["Land"].isin(north_africa)]`. Hier wird kein neuer Datensatz erstellt, sondern nur ein neuer Name für einen Ausschnitt (View) des Datensatzes vergeben. **Das heißt: Änderst du etwas in `na_subset`, siehst du die Änderung auch in `data` (und umgekehrt).
#
# Wenn du wirklich unabhängig weiterarbeiten willst, musst du eine echte Kopie machen:

# %%
north_africa = [
    "Algeria",
    "Egypt",
    "Libya",
    "Mauritania",
    "Morocco",
    "Sudan",
    "Tunisia",
    "Western Sahara"
]

true_na_subset = data[data["Land"].isin(north_africa)].copy()
true_na_subset
# Out:
#               Land Country_Code  Fläche_Total_km2  Fläche_Land_km2  \
# 0          Algeria           ag       2381740.000      2381740.000
# 14           Egypt           eg       1001450.000       995450.000
# 26           Libya           ly       1759540.000      1759540.000
# 30      Mauritania           mr       1030700.000      1030700.000
# 32         Morocco           mo        716550.000       716300.000
# 45           Sudan           su       1861484.000      1731671.000
# 50         Tunisia           ts        163610.000       155360.000
# 52  Western Sahara           wi               NaN       266000.000
#
#     Fläche_Wasser_km2  Küstenlänge_km  Landnutzung_Landwirtschaft_%  \
# 0               0.000             998                        17.300
# 14           6000.000            2450                         4.100
# 26              0.000            1770                         8.700
# 30              0.000             754                        38.500
# ...

# %% [markdown]
# ## Export

# %%
na_subset.to_excel('./export/na_subset.xlsx', index=False)
