# %% [markdown]
# # Correlation Analysis with Python
#
# This example uses **Pandas** and **SciKit Learn** for data analysis and **Vega Altair** for plotting.
# Install the libraries with the following commands.
#
# ```shell
# pip install pandas
# pip install "altair[all]"
# pip install -U scikit-learn
# ```

# %%
import pandas as pd
import altair as alt
alt.data_transformers.enable("vegafusion")
from sklearn.linear_model import LinearRegression

# %%
# Load the dataset
file_path = './data/CAMELS_CH_obs_based_2152.csv'  # Adjust to your actual file path
data = pd.read_csv(file_path, sep=';')

# Preview the first few rows to understand the structure
data.head()
# Out:
#          date  discharge_vol(m3/s)  discharge_spec(mm/d)  waterlevel(m)  \
# 0  1981-01-01               35.556                 1.363        430.839
# 1  1981-01-02               35.459                 1.359        430.838
# 2  1981-01-03               35.619                 1.365        430.840
# 3  1981-01-04               38.814                 1.488        430.888
# 4  1981-01-05               41.653                 1.597        430.930
#
#    precipitation(mm/d)  temperature_min(°C)  temperature_mean(°C)  \
# 0                 5.28                -8.99                 -3.34
# 1                 8.95                -7.52                 -5.08
# 2                29.21                -4.55                 -0.59
# 3                35.71                -7.88                 -2.91
# 4                 7.14                -9.62                 -8.12
#
#    temperature_max(°C)  rel_sun_dur(%)  swe(mm)
# 0                 1.86            0.87      NaN
# 1                -0.91            0.06      NaN
# 2                 2.91            5.41      NaN
# 3                 0.25            0.04      NaN
# 4                -6.91            0.56      NaN

# %%
# Basic summary statistics
data.describe()
# Out:
#        discharge_vol(m3/s)  discharge_spec(mm/d)  waterlevel(m)  \
# count         14610.000000          14610.000000   14610.000000
# mean            109.042704              4.179872     431.519220
# std              67.337396              2.581206       0.578028
# min              22.392000              0.858000     430.557000
# 25%              54.379000              2.084250     431.037000
# 50%              89.192000              3.419000     431.405000
# 75%             152.378250              5.841250     431.953000
# max             470.260000             18.026000     433.792000
#
#        precipitation(mm/d)  temperature_min(°C)  temperature_mean(°C)  \
# count         14610.000000         14610.000000          14610.000000
# mean              4.615357             0.860379              4.514891
# std               8.268318             6.524576              6.924003
# min               0.000000           -26.750000            -22.710000
# 25%               0.010000            -3.990000             -0.720000
# 50%               0.670000             1.040000              4.550000
# 75%               5.930000             6.090000              9.950000
# max              93.340000            16.690000             22.100000
#
#        temperature_max(°C)  rel_sun_dur(%)      swe(mm)
# count         14610.000000    14610.000000  8157.000000
# mean              8.321746       41.838642   122.031984
# std               7.680192       36.104614   124.521328
# min             -17.720000        0.030000     0.000000
# 25%               2.472500        4.392500     9.850000
# 50%               8.240000       36.450000    81.510000
# 75%              14.210000       76.610000   209.210000
# max              28.940000       99.910000   597.320000

# %% [markdown]
# ## Creating a Correlation Matrix
#
# This gives you a correlation coefficient (like Pearson’s r) between every pair of numeric columns. But it does not tell you if that correlation is statistically significant. The statistical significance asks the question if this correlation could have happened just by chance in random data.

# %%
# Calculate correlation matrix (default = Pearson)
correlation_matrix = data.corr(numeric_only=True)
correlation_matrix
# Out:
#                       discharge_vol(m3/s)  discharge_spec(mm/d)  \
# discharge_vol(m3/s)              1.000000              1.000000
# discharge_spec(mm/d)             1.000000              1.000000
# waterlevel(m)                    0.990703              0.990703
# precipitation(mm/d)              0.117266              0.117267
# temperature_min(°C)              0.569567              0.569568
# temperature_mean(°C)             0.561815              0.561816
# temperature_max(°C)              0.544722              0.544723
# rel_sun_dur(%)                  -0.059546             -0.059546
# swe(mm)                         -0.090138             -0.090137
#
#                       waterlevel(m)  precipitation(mm/d)  temperature_min(°C)  \
# discharge_vol(m3/s)        0.990703             0.117266             0.569567
# discharge_spec(mm/d)       0.990703             0.117267             0.569568
# waterlevel(m)              1.000000             0.122967             0.593996
# precipitation(mm/d)        0.122967             1.000000             0.053461
# temperature_min(°C)        0.593996             0.053461             1.000000
# temperature_mean(°C)       0.586448             0.016646             0.984455
# temperature_max(°C)        0.569240            -0.004874             0.957767
# rel_sun_dur(%)            -0.061233            -0.432920             0.110849
# swe(mm)                   -0.102539            -0.036128            -0.463726
#
#                       temperature_mean(°C)  temperature_max(°C)  \
# discharge_vol(m3/s)               0.561815             0.544722
# discharge_spec(mm/d)              0.561816             0.544723
# waterlevel(m)                     0.586448             0.569240
# precipitation(mm/d)               0.016646            -0.004874
# temperature_min(°C)               0.984455             0.957767
# temperature_mean(°C)              1.000000             0.991201
# temperature_max(°C)               0.991201             1.000000
# rel_sun_dur(%)                    0.217544             0.292959
# swe(mm)                          -0.432833            -0.406579
#
#                       rel_sun_dur(%)   swe(mm)
# discharge_vol(m3/s)        -0.059546 -0.090138
# discharge_spec(mm/d)       -0.059546 -0.090137
# waterlevel(m)              -0.061233 -0.102539
# precipitation(mm/d)        -0.432920 -0.036128
# temperature_min(°C)         0.110849 -0.463726
# temperature_mean(°C)        0.217544 -0.432833
# temperature_max(°C)         0.292959 -0.406579
# rel_sun_dur(%)              1.000000 -0.034477
# swe(mm)                    -0.034477  1.000000

# %%
# Display correlation for selected pair (precipitation vs discharge)
correlation = correlation_matrix.loc['precipitation(mm/d)', 'discharge_vol(m3/s)']
print(f"Correlation between precipitation and discharge: {correlation:.2f}")
# Out:
# Correlation between precipitation and discharge: 0.12

# %% [markdown]
# ### Statistical Significance
#
# The significance can be tested with a p-value and with another library. We will not cover this during the introduction.
#
# ```python
# from scipy.stats import pearsonr
#
# corr, p_value = pearsonr(df['precipitation(mm/d)'], df['discharge_vol(m3/s)'])
#
# # The correlation coefficient tells you how strong and in what direction the relationship is.
# # The p-value tells you how likely you’d see this correlation in random data.
# # If p < 0.05, the correlation is usually considered statistically significant (less than 5% chance this happened randomly).
# print(f'Pearson correlation: {corr:.2f}')
# print(f'p-value: {p_value:.5f}')
# ```

# %% [markdown]
# ## Linear Regression

# %%
# Example: Correlation between precipitation and discharge
precipitation = data['precipitation(mm/d)']
discharge = data['discharge_vol(m3/s)']

X = precipitation.values.reshape(-1, 1)
y = discharge.values

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
regression_data = pd.DataFrame({
    'Precipitation': precipitation,
    'Discharge': discharge,
    'Predicted Discharge': model.predict(X)
})

# %%
# Scatter plot with regression line using Altair
scatter_plot = alt.Chart(regression_data).mark_point().encode(
    x='Precipitation',
    y='Discharge',
    tooltip=['Precipitation', 'Discharge']
)

regression_line = alt.Chart(regression_data).mark_line(color='red').encode(
    x='Precipitation',
    y='Predicted Discharge'
)

(scatter_plot + regression_line).properties(
    width=600,
    height=400,
    title=f'Linear Regression: Precipitation vs Discharge (r={correlation:.2f})'
).show()

# Summary of regression
print(f"Regression Coefficient (Slope): {model.coef_[0]:.3f}")
print(f"Intercept: {model.intercept_:.3f}")

# Encourage students to experiment with other pairs of variables
print("\nTry analyzing other pairs like temperature vs discharge, or SWE vs discharge!")
# Out:
# alt.LayerChart(...)
# Regression Coefficient (Slope): 0.955
# Intercept: 104.635
#
# Try analyzing other pairs like temperature vs discharge, or SWE vs discharge!
