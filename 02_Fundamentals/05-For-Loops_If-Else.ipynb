# %% [markdown]
# # 05 Loops / If-Else

# %% [markdown]
# ## Looping through Lists

# %%
grime_mcs = ["Skepta", "Wiley", "D Double E", "Flow Dan"]

for mc in grime_mcs:
    print(mc)
# Out:
# Skepta
# Wiley
# D Double E
# Flow Dan

# %% [markdown]
# ## Looping through Ranges

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10,15):
    print(i)
# Out:
# 10
# 11
# 12
# 13
# 14

# %% [markdown]
# ## Looping Through Dictionaries

# %%
person = {"name": "Alice", "age": 25, "city": "New York"}
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
# by key and value pair with 'items()'
for k, v in person.items():
    print(k, v)
# Out:
# name Alice
# age 25
# city New York

# %%
# by key
for k in person.keys():
    print(k)
# Out:
# name
# age
# city

# %%
# by value
for v in person.values():
    print(v)
# Out:
# Alice
# 25
# New York

# %% [markdown]
# ## Zwischenaufgabe
#
# 1. Schreibe eine For Loop, die die Zahlen von 0-9 hoch 2 rechnet.
# 2. Schreibe eine For Loop, welche das Zeichen ```'*'``` erst einmal, dann zweimal, ... bis sieben mal multipliziert.

# %% [markdown]
# ### Lösung Zwischenaufgabe

# %%
for i in range(9):
    print(i*2)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16

# %%
for i in range (1, 8):
    print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# ## If-Else

# %%
# simple if / else
x = 4

if x > 3:
    print("x ist grösser als 3")
else:
    print("x kleiner oder gleich 3")

# %%
# if, else if, else

name = 'max'

if name == 'darjan':
    print('sketching class')
elif name == 'irene':
    print('statistics class')
else:
    print('python class')
# Out:
# python class

# %% [markdown]
# ## Zwischenaufgabe
#
# 1. Schreibe ein If-Else-Statement das prüft ob 'x' ein Integer ist, wenn ja soll es ein Print-Statement 'x is int' ausgeben, ansonsten den Type.
# 2. Schreibe ein If-Else-Statement das sagt ob der String 'Katze' länger ist als der String 'Hund'

# %%
x = '10'

# deine Lösung

# %% [markdown]
# ### Lösung Zwischenaufgabe

# %%
x = '10'

if type(x) == int:
    print("x is int")
else: 
    print(type(x))
# Out:
# int

# %%
a = "Katze"
b = "Maus"

if len(a) > len(b):
    print("a ist länger als b")
else:
    print("b ist länger als a")
