# %% [markdown]
# # Vega Altair
#
# Vega-Altair is a declarative statistical visualization library for Python, based on Vega and Vega-Lite. It offers a powerful and concise grammar that enables you to quickly build a wide range of statistical visualizations.
#
# You can install Altair with the terminal command:
#
# `pip install "altair[all]"`
#
# Check the [installation guide](https://altair-viz.github.io/getting_started/installation.html) for more infos.

# %%
#import libraries
import altair as alt
import pandas as pd
from datetime import datetime as dt

# %%
#load data
df = pd.read_csv("data/movies_imdb.csv")
df.head(2)
# Out:
#    imdbID             title  year     rating runtime               genre  \
# 0       1        Carmencita  1894  NOT RATED   1 min  Documentary, Short
# 1       5  Blacksmith Scene  1893    UNRATED   1 min               Short
#
#      released              director writer                      cast  ...  \
# 0         NaN  William K.L. Dickson    NaN                Carmencita  ...
# 1  1893-05-09  William K.L. Dickson    NaN  Charles Kayser, John Ott  ...
#
#    imdbRating  imdbVotes                                             poster  \
# 0         5.9     1032.0  https://m.media-amazon.com/images/M/MV5BMjAzND...
# 1         6.2     1189.0                                                NaN
#
#                                                 plot  \
# 0  Performing on what looks like a small wooden s...
# 1  Three men hammer on an anvil and pass a bottle...
#
#                                             fullplot language country  awards  \
# 0  Performing on what looks like a small wooden s...      NaN     USA     NaN
# 1  A stationary camera looks at a large anvil wit...      NaN     USA  1 win.
#
#                      lastupdated   type
# 0  2015-08-26 00:03:45.040000000  movie
# 1  2015-08-26 00:03:50.133000000  movie
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Data Cleaning

# %%
#fix the error in year
df['year'] = df['year'].str.replace('�', '')
# now convert the column
df["year"] = df["year"].astype(int)
# convert released to date
df['released'] = pd.to_datetime( df['released'])

# %%
df.dtypes
# Out:
# imdbID                  int64
# title                  object
# year                    int64
# rating                 object
# runtime                object
# genre                  object
# released       datetime64[ns]
# director               object
# writer                 object
# cast                   object
# metacritic            float64
# imdbRating            float64
# imdbVotes             float64
# poster                 object
# plot                   object
# fullplot               object
# language               object
# country                object
# awards                 object
# lastupdated            object
# type                   object
# dtype: object

# %% [markdown]
# ## Plotting =)

# %%
# which country has made the most films? 
top_countries = df['country'].value_counts().reset_index().head(5)

top_countries
# Out:
#   country  count
# 0     USA  20589
# 1      UK   2550
# 2  France   1683
# 3   Japan   1468
# 4   Italy   1208

# %% [markdown]
# ### Anatomy of an Altair chart
# An altair plot always follows this schema:
#
#     alt.Chart(df).mark_bar().encode(
#         x = 'column_A',
#         y = 'column_B
#     )
#
# `Chart()`: variable inside sets from which dataframe data should be plotted <br>
# `mark_bar()`: choose which form the plot should take<br>
# `encode`: set which columns to plot

# %% [markdown]
# ##### Bar chart

# %%
# Bar chart
alt.Chart(top_countries).mark_bar().encode(
    x = 'count',
    y = 'country'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Plot types
#
# There is
# * `mark_bar`
# * `mark_line`
# * `mark_circle`
# * `mark_point`
# * `mark_boxplot`
# * `mark_square`

# %% [markdown]
# ##### Line chart

# %%
df['year'].sort_values().tail(10)
# Out:
# 43545        2017
# 45666        2018
# 45877        2019
# 40155    19821986
# 15802    19941998
# 20546    19981999
# 24060    20012004
# 30643    20062007
# 29443    20062012
# 31425    20062012
# Name: year, dtype: int64

# %%
# we leave out any double years for the sake of this demonstration
df = df[df['year']<2025]

# %%
# count number of films per year
films_per_year = df.groupby('year')['country'].count().reset_index()
films_per_year
# Out:
#      year  country
# 0    1874        1
# 1    1880        1
# 2    1887        1
# 3    1888        2
# 4    1890        4
# ..    ...      ...
# 129  2015     2055
# 130  2016      506
# 131  2017       41
# 132  2018        1
# 133  2019        1
#
# [134 rows x 2 columns]

# %%
alt.Chart(films_per_year).mark_line().encode(
    x = 'year',
    y = 'country',
    tooltip = ['year', 'country']
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Dot plot

# %%
best_rated = df.sort_values('imdbRating', ascending=False).head(1000)

# %%
this_df = df[df['imdbVotes']>10000]
this_df
# Out:
#         imdbID                                              title  year  \
# 25         417                                 A Trip to the Moon  1902
# 106       4972                              The Birth of a Nation  1915
# 208      10323                        The Cabinet of Dr. Caligari  1920
# 254      12349                                            The Kid  1921
# 290      13442                                          Nosferatu  1922
# ...        ...                                                ...   ...
# 44756  4044364                                        Citizenfour  2014
# 45005  4178092                                           The Gift  2015
# 45092  4229236                            Cobain: Montage of Heck  2015
# 45129  4257858  Going Clear: Scientology and the Prison of Belief  2015
# 45363  4430212                                           Drishyam  2015
#
#           rating runtime                          genre   released  \
# 25          TV-G      13      Short, Adventure, Fantasy 1902-10-04
# 106    NOT RATED     165        Drama, History, Romance 1915-03-03
# 208      UNRATED      67        Crime, Horror, Thriller 1921-03-19
# 254    NOT RATED      68          Comedy, Drama, Family 1921-02-06
# 290      UNRATED      81                         Horror 1929-06-03
# ...          ...     ...                            ...        ...
# 44756          R     114                    Documentary 2015-02-23
# 45005          R     108              Mystery, Thriller 2015-08-07
# 45092      TV-MA     145  Documentary, Biography, Music 2015-05-04
# 45129  NOT RATED     119                    Documentary 2015-06-25
# 45363        NaN     163       Drama, Mystery, Thriller 2015-07-31
#
#               director                                             writer  \
# 25      Georges M�li�s                                                NaN
# 106      D.W. Griffith  Thomas Dixon Jr. (adapted from his novel: "The...
# 208       Robert Wiene          Carl Mayer (story), Hans Janowitz (story)
# 254    Charles Chaplin                                    Charles Chaplin
# 290        F.W. Murnau  Henrik Galeen (screen play), Bram Stoker (base...
# ...                ...                                                ...
# 44756    Laura Poitras                                                NaN
# 45005    Joel Edgerton                                      Joel Edgerton
# 45092     Brett Morgen                                       Brett Morgen
# 45129      Alex Gibney                Alex Gibney, Lawrence Wright (book)
# 45363  Nishikant Kamat  Jeethu Joseph (original story), Upendra Sidhay...
#
#                                                     cast  ...  imdbRating  \
# 25               Fran�ois Lallement, Jules-Eug�ne Legris  ...         8.2
# 106    Lillian Gish, Mae Marsh, Henry B. Walthall, Mi...  ...         6.8
# 208    Werner Krauss, Conrad Veidt, Friedrich Feher, ...  ...         8.1
# 254    Carl Miller, Edna Purviance, Jackie Coogan, Ch...  ...         8.4
# 290    Max Schreck, Gustav von Wangenheim, Greta Schr...  ...         8.0
# ...                                                  ...  ...         ...
# 44756  Edward Snowden, Glenn Greenwald, William Binne...  ...         8.2
# 45005  Jason Bateman, Rebecca Hall, Joel Edgerton, Al...  ...         7.6
# 45092  Aaron Burckhard, Chad Channing, Don Cobain, Je...  ...         7.7
# 45129  Lawrence Wright, Mike Rinder, Marty Rathbun, P...  ...         8.2
# 45363       Ajay Devgn, Shriya Saran, Tabu, Ishita Dutta  ...         8.9
#
#        imdbVotes                                             poster  \
# 25       23904.0  https://m.media-amazon.com/images/M/MV5BMTQzMD...
# 106      15715.0  https://m.media-amazon.com/images/M/MV5BMTY0OD...
# 208      34504.0  https://m.media-amazon.com/images/M/MV5BMTk2Nj...
# 254      56858.0  https://m.media-amazon.com/images/M/MV5BMTkzNT...
# 290      63322.0  https://m.media-amazon.com/images/M/MV5BMzgwNz...
# ...          ...                                                ...
# 44756    20610.0  https://m.media-amazon.com/images/M/MV5BMTc0MT...
# 45005    12823.0  https://m.media-amazon.com/images/M/MV5BMTQzMj...
# 45092    13973.0  https://m.media-amazon.com/images/M/MV5BMjIyOT...
# 45129    13687.0  https://m.media-amazon.com/images/M/MV5BMjMwMT...
# 45363    11752.0  https://m.media-amazon.com/images/M/MV5BMTYyMj...
#
#                                                     plot  \
# 25     A group of astronomers go on an expedition to ...
# 106    The Civil War divides friends and destroys fam...
# 208    Dr. Caligari's somnambulist, Cesare, and his d...
# 254    The Tramp cares for an abandoned child, but ev...
# 290    Vampire Count Orlok expresses interest in a ne...
# ...                                                  ...
# 44756  A documentarian and a reporter travel to Hong ...
# 45005  A young married couple's lives are thrown into...
# 45092  An authorized documentary on the late musician...
# 45129  An in-depth look at the inner-workings of the ...
# 45363  Desperate measures are taken by a man who trie...
#
#                                                 fullplot  \
# 25     A group of men travel to the moon by being sho...
# 106    Two brothers, Phil and Ted Stoneman, visit the...
# 208    Francis, a young man, recalls in his memory th...
# 254    The opening title reads: "A comedy with a smil...
# 290    Wisbourg, Germany based estate agent Knock dis...
# ...                                                  ...
# 44756  In January 2013, Laura Poitras started receivi...
# 45005  Simon and Robyn are a young married couple who...
# 45092  An authorized documentary on the late musician...
# 45129  A devastating two hour documentary based on La...
# 45363  Vijay Salgaonkar runs a cable TV network in a ...
#
#                           language           country  \
# 25                             NaN            France
# 106                            NaN               USA
# 208                         German           Germany
# 254                        English               USA
# 290                         German           Germany
# ...                            ...               ...
# 44756  English, Portuguese, German  USA, Germany, UK
# 45005                      English    Australia, USA
# 45092                      English               USA
# 45129                      English               USA
# 45363                        Hindi             India
#
#                                                 awards  \
# 25                                                 NaN
# 106                                            2 wins.
# 208                                                NaN
# 254                                             1 win.
# 290                              1 win & 1 nomination.
# ...                                                ...
# 44756   Won 1 Oscar. Another 43 wins & 25 nominations.
# 45005                                              NaN
# 45092  Nominated for 6 Primetime Emmys. Another 1 win.
# 45129                                              NaN
# 45363                                              NaN
#
#                          lastupdated   type
# 25     2015-09-01 00:16:55.443000000  movie
# 106    2015-09-11 00:32:27.763000000  movie
# 208    2015-08-26 00:40:25.337000000  movie
# 254    2015-09-05 00:24:11.143000000  movie
# 290    2015-08-21 00:04:53.453000000  movie
# ...                              ...    ...
# 44756  2015-08-27 00:14:57.227000000  movie
# 45005  2015-09-05 00:00:36.160000000  movie
# 45092  2015-09-17 04:40:35.987000000  movie
# 45129  2015-09-10 17:47:44.460000000  movie
# 45363  2015-09-06 01:05:41.510000000  movie
#
# [6426 rows x 21 columns]

# %%
alt.Chart(this_df.head(1000)).mark_point().encode(
    x = 'imdbRating',
    y = 'imdbVotes',
    tooltip = ['title', 'imdbRating', 'imdbVotes']    
)
# Out:
# alt.Chart(...)

# %%
# Out:
# alt.Chart(...)
