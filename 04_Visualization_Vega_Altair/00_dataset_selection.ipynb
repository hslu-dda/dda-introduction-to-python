# %% [markdown]
# # Vega Altair
#
# Vega-Altair is a declarative statistical visualization library for Python, based on Vega and Vega-Lite. It offers a powerful and concise grammar that enables you to quickly build a wide range of statistical visualizations.
#
# You can install Altair with the terminal command:
#
# `pip install "altair[all]"`
#
# Check the [installation guide](https://altair-viz.github.io/getting_started/installation.html) for more infos.

# %%
#import libraries
import altair as alt
import pandas as pd
from datetime import datetime as dt

# %%
#load data
df_raw = pd.read_csv("data/pokemon.csv")
df_raw.head(2)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 0             2.0            1.0  ...             88.1               1
# 1             2.0            1.0  ...             88.1               2
#
#    sp_attack  sp_defense  speed  type1   type2  weight_kg  generation  \
# 0         65          65     45  grass  poison        6.9           1
# 1         80          80     60  grass  poison       13.0           1
#
#    is_legendary
# 0             0
# 1             0
#
# [2 rows x 41 columns]

# %% [markdown]
# ### Data Cleaning

# %%
df_raw.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
df_raw = df_raw[['name', 'classfication', 'height_m', 'weight_kg', 'generation', 'is_legendary', 'attack','hp', 'base_happiness', 'capture_rate']]

# %%
df = df[df['generation']==1]

# %%
df
# Out:
#            name        classfication  height_m  weight_kg  generation  \
# 0     Bulbasaur         Seed Pokémon       0.7        6.9           1
# 1       Ivysaur         Seed Pokémon       1.0       13.0           1
# 2      Venusaur         Seed Pokémon       2.0      100.0           1
# 3    Charmander       Lizard Pokémon       0.6        8.5           1
# 4    Charmeleon        Flame Pokémon       1.1       19.0           1
# ..          ...                  ...       ...        ...         ...
# 146     Dratini       Dragon Pokémon       1.8        3.3           1
# 147   Dragonair       Dragon Pokémon       4.0       16.5           1
# 148   Dragonite       Dragon Pokémon       2.2      210.0           1
# 149      Mewtwo      Genetic Pokémon       2.0      122.0           1
# 150         Mew  New Species Pokémon       0.4        4.0           1
#
#      is_legendary  attack   hp  base_happiness capture_rate
# 0               0      49   45              70           45
# 1               0      62   60              70           45
# 2               0     100   80              70           45
# 3               0      52   39              70           45
# 4               0      64   58              70           45
# ..            ...     ...  ...             ...          ...
# 146             0      64   41              35           45
# 147             0      84   61              35           45
# 148             0     134   91              35           45
# 149             1     150  106               0            3
# 150             1     100  100             100           45
#
# [151 rows x 10 columns]

# %%
little_ones = df.sort_values('height_m').head(5)
little_ones
# Out:
#           name      classfication  height_m  weight_kg  generation  \
# 80   Magnemite     Magnet Pokémon       0.3        6.0           1
# 132      Eevee  Evolution Pokémon       0.3        6.5           1
# 131      Ditto  Transform Pokémon       0.3        4.0           1
# 89    Shellder    Bivalve Pokémon       0.3        4.0           1
# 9     Caterpie       Worm Pokémon       0.3        2.9           1
#
#      is_legendary  attack  hp  base_happiness capture_rate
# 80              0      35  25              70          190
# 132             0      55  55              70           45
# 131             0      48  48              70           35
# 89              0      65  30              70          190
# 9               0      30  45              70          255

# %% [markdown]
# ## Plotting =)

# %% [markdown]
# ### Anatomy of an Altair chart
# An altair plot always follows this schema:
#
#     alt.Chart(df).mark_bar().encode(
#         x = 'column_A',
#         y = 'column_B
#     )
#
# `Chart()`: variable inside sets from which dataframe data should be plotted <br>
# `mark_bar()`: choose which form the plot should take<br>
# `encode`: set which columns to plot

# %% [markdown]
# ##### Bar chart

# %%
little_ones
# Out:
#           name      classfication  height_m  weight_kg  generation  \
# 80   Magnemite     Magnet Pokémon       0.3        6.0           1
# 132      Eevee  Evolution Pokémon       0.3        6.5           1
# 131      Ditto  Transform Pokémon       0.3        4.0           1
# 89    Shellder    Bivalve Pokémon       0.3        4.0           1
# 9     Caterpie       Worm Pokémon       0.3        2.9           1
#
#      is_legendary  attack  hp  base_happiness capture_rate
# 80              0      35  25              70          190
# 132             0      55  55              70           45
# 131             0      48  48              70           35
# 89              0      65  30              70          190
# 9               0      30  45              70          255

# %%
# Out:
#    generation  count
# 1           1    151
# 4           2    100
# 2           3    135
# 3           4    107
# 0           5    156
# 6           6     72
# 5           7     80

# %%
# Bar chart
alt.Chart(little_ones).mark_bar().encode(
    x = 'weight_kg',
    y = 'name'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Plot types
#
# There is
# * `mark_bar`
# * `mark_line`
# * `mark_point`
# * `mark_boxplot`
# * `mark_square`

# %% [markdown]
# ##### Line chart
# Line charts machen besonders bei zeitlichen Abläufen Sinn.

# %%
# wie viele Pokemons gab es pro Generation?
generation = df_raw.value_counts('generation').reset_index().sort_values('generation')
generation

# %%
# Line chart
alt.Chart(generation).mark_line().encode(
    x = 'generation',
    y = 'count'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Dot plot
# Dot plots eignen sich gut um Zusammenhänge zwischen Zahlenwerten aufzuzeigen.

# %%
df
# Out:
#            name        classfication  height_m  weight_kg  generation  \
# 0     Bulbasaur         Seed Pokémon       0.7        6.9           1
# 1       Ivysaur         Seed Pokémon       1.0       13.0           1
# 2      Venusaur         Seed Pokémon       2.0      100.0           1
# 3    Charmander       Lizard Pokémon       0.6        8.5           1
# 4    Charmeleon        Flame Pokémon       1.1       19.0           1
# ..          ...                  ...       ...        ...         ...
# 146     Dratini       Dragon Pokémon       1.8        3.3           1
# 147   Dragonair       Dragon Pokémon       4.0       16.5           1
# 148   Dragonite       Dragon Pokémon       2.2      210.0           1
# 149      Mewtwo      Genetic Pokémon       2.0      122.0           1
# 150         Mew  New Species Pokémon       0.4        4.0           1
#
#      is_legendary  attack   hp  base_happiness capture_rate
# 0               0      49   45              70           45
# 1               0      62   60              70           45
# 2               0     100   80              70           45
# 3               0      52   39              70           45
# 4               0      64   58              70           45
# ..            ...     ...  ...             ...          ...
# 146             0      64   41              35           45
# 147             0      84   61              35           45
# 148             0     134   91              35           45
# 149             1     150  106               0            3
# 150             1     100  100             100           45
#
# [151 rows x 10 columns]

# %%
# Je grösser desto schwerer?

alt.Chart(df).mark_point().encode(
    x = 'weight_kg',
    y = 'height_m', 
    tooltip = ['name', 'weight_kg', 'height_m']
)
# Out:
# alt.Chart(...)

# %%
df.head(1)
# Out:
#         name classfication  height_m  weight_kg  generation  is_legendary  \
# 0  Bulbasaur  Seed Pokémon       0.7        6.9           1             0
#
#    attack  hp  base_happiness capture_rate
# 0      49  45              70           45

# %%
# ... da ist eine Spalte noch nicht im richtigen Datentyp
df['capture_rate'] = df['capture_rate'].astype(int)

# %%
# je seltener desto mehr Attack-Punkte?
alt.Chart(df).mark_point().encode(
    x = 'attack',
    y = 'capture_rate', 
    tooltip = ['name']
)
# Out:
# alt.Chart(...)

# %%
df.head(1)
# Out:
#         name classfication  height_m  weight_kg  generation  is_legendary  \
# 0  Bulbasaur  Seed Pokémon       0.7        6.9           1             0
#
#    attack  hp  base_happiness capture_rate
# 0      49  45              70           45

# %%
df['classfication'].value_counts().head(15)
# Out:
# classfication
# Mouse Pokémon         6
# Dragon Pokémon        5
# Poison Pin Pokémon    4
# Flame Pokémon         4
# Tadpole Pokémon       3
# Psi Pokémon           3
# Superpower Pokémon    3
# Drill Pokémon         3
# Seed Pokémon          3
# Shellfish Pokémon     3
# Goldfish Pokémon      2
# Gas Pokémon           2
# Poison Gas Pokémon    2
# Egg Pokémon           2
# Flycatcher Pokémon    2
# Name: count, dtype: int64

# %%
classfication_filter = ['Mouse Pokémon','Dragon Pokémon','Poison Pin Pokémon','Flame Pokémon','Tadpole Pokémon','Psi Pokémon']

df_classified = df[df['classfication'].isin(classfication_filter)]
df_classified
# Out:
#            name       classfication  height_m  weight_kg  generation  \
# 4    Charmeleon       Flame Pokémon       1.1       19.0           1
# 5     Charizard       Flame Pokémon       1.7       90.5           1
# 18      Rattata       Mouse Pokémon       NaN        NaN           1
# 19     Raticate       Mouse Pokémon       NaN        NaN           1
# 24      Pikachu       Mouse Pokémon       0.4        6.0           1
# 25       Raichu       Mouse Pokémon       NaN        NaN           1
# 26    Sandshrew       Mouse Pokémon       NaN        NaN           1
# 27    Sandslash       Mouse Pokémon       NaN        NaN           1
# 28     Nidoran♀  Poison Pin Pokémon       0.4        7.0           1
# 29     Nidorina  Poison Pin Pokémon       0.8       20.0           1
# 31     Nidoran♂  Poison Pin Pokémon       0.5        9.0           1
# 32     Nidorino  Poison Pin Pokémon       0.9       19.5           1
# 59      Poliwag     Tadpole Pokémon       0.6       12.4           1
# 60    Poliwhirl     Tadpole Pokémon       1.0       20.0           1
# 61    Poliwrath     Tadpole Pokémon       1.3       54.0           1
# 62         Abra         Psi Pokémon       0.9       19.5           1
# 63      Kadabra         Psi Pokémon       1.3       56.5           1
# 64     Alakazam         Psi Pokémon       1.5       48.0           1
# 115      Horsea      Dragon Pokémon       0.4        8.0           1
# 116      Seadra      Dragon Pokémon       1.2       25.0           1
# 135     Flareon       Flame Pokémon       0.9       25.0           1
# 145     Moltres       Flame Pokémon       2.0       60.0           1
# 146     Dratini      Dragon Pokémon       1.8        3.3           1
# 147   Dragonair      Dragon Pokémon       4.0       16.5           1
# 148   Dragonite      Dragon Pokémon       2.2      210.0           1
#
#      is_legendary  attack  hp  base_happiness capture_rate
# 4               0      64  58              70           45
# 5               0     104  78              70           45
# 18              0      56  30              70          255
# 19              0      71  75              70          127
# 24              0      55  35              70          190
# 25              0      85  60              70           75
# 26              0      75  50              70          255
# 27              0     100  75              70           90
# 28              0      47  55              70          235
# 29              0      62  70              70          120
# 31              0      57  46              70          235
# 32              0      72  61              70          120
# 59              0      50  40              70          255
# 60              0      65  65              70          120
# 61              0      95  90              70           45
# 62              0      20  25              70          200
# 63              0      35  40              70          100
# 64              0      50  55              70           50
# 115             0      40  30              70          225
# 116             0      65  55              70           75
# 135             0     130  65              70           45
# 145             1     100  90              35            3
# 146             0      64  41              35           45
# 147             0      84  61              35           45
# 148             0     134  91              35           45

# %%
alt.Chart(df_classified).mark_boxplot().encode(
    x = 'classfication', 
    y = 'attack', 
    tooltip=['name']
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Heatmap
# Heatmap eignen sich gut um Werte in Farbe darzustellen, wobei die Achsen direkt miteinader im Bezug stehen. Sie kommen vor allem bei zeitlichen Daten zur Anwendung, z.B. um Werte über ein Jahr hinweg pro Tage & Monat darzustellen.

# %%
# Weil unser Dataframe noch keine Zeitdaten hat fügen wir fiktive Daten ein, wann wir das Pokemon gefangen haben. 
import numpy as np

df_capture = df.copy()
df_capture["capture_date"] = pd.to_datetime(
    np.random.choice(pd.date_range("2024-01-01", "2024-12-31"), size=len(df_capture))
)

# %%
df_capture
# Out:
#            name        classfication  height_m  weight_kg  generation  \
# 0     Bulbasaur         Seed Pokémon       0.7        6.9           1
# 1       Ivysaur         Seed Pokémon       1.0       13.0           1
# 2      Venusaur         Seed Pokémon       2.0      100.0           1
# 3    Charmander       Lizard Pokémon       0.6        8.5           1
# 4    Charmeleon        Flame Pokémon       1.1       19.0           1
# ..          ...                  ...       ...        ...         ...
# 146     Dratini       Dragon Pokémon       1.8        3.3           1
# 147   Dragonair       Dragon Pokémon       4.0       16.5           1
# 148   Dragonite       Dragon Pokémon       2.2      210.0           1
# 149      Mewtwo      Genetic Pokémon       2.0      122.0           1
# 150         Mew  New Species Pokémon       0.4        4.0           1
#
#      is_legendary  attack   hp  base_happiness  capture_rate capture_date
# 0               0      49   45              70            45   2024-05-17
# 1               0      62   60              70            45   2024-01-28
# 2               0     100   80              70            45   2024-05-04
# 3               0      52   39              70            45   2024-07-05
# 4               0      64   58              70            45   2024-09-07
# ..            ...     ...  ...             ...           ...          ...
# 146             0      64   41              35            45   2024-05-05
# 147             0      84   61              35            45   2024-02-01
# 148             0     134   91              35            45   2024-11-12
# 149             1     150  106               0             3   2024-12-29
# 150             1     100  100             100            45   2024-10-13
#
# [151 rows x 11 columns]

# %%
df_capture_grouped = df_capture.groupby('capture_date')['name'].count().reset_index()
df_capture_grouped = df_capture_grouped.rename(columns={'name':'count'})

# %%
df_capture_grouped
# Out:
#     capture_date  count
# 0     2024-01-02      1
# 1     2024-01-08      1
# 2     2024-01-10      1
# 3     2024-01-19      1
# 4     2024-01-23      1
# ..           ...    ...
# 120   2024-12-22      1
# 121   2024-12-23      1
# 122   2024-12-28      1
# 123   2024-12-29      2
# 124   2024-12-30      1
#
# [125 rows x 2 columns]

# %%
alt.Chart(df_capture_grouped).mark_rect().encode(
    x = alt.X('date(capture_date):O'),
    y = alt.Y('month(capture_date):O'),
    color = alt.Color('count:O')
)
# Out:
# alt.Chart(...)

# %%
from vega_datasets import data

source = data.seattle_weather()

alt.Chart(source, title="Daily Max Temperatures (C) in Seattle, WA").mark_rect().encode(
    alt.X("date(date):O").title("Day").axis(format="%e", labelAngle=0),
    alt.Y("month(date):O").title("Month"),
    alt.Color("max(temp_max)").title(None),
    tooltip=[
        alt.Tooltip("monthdate(date)", title="Date"),
        alt.Tooltip("max(temp_max)", title="Max Temp"),
    ],
).configure_view(
    step=13,
    strokeWidth=0
).configure_axis(
    domain=False
)
# Out:
# alt.Chart(...)
